# %%
#Setting up the notebook and loading the dataset

# %%
#Configure Google Drive
from google.colab import drive
drive.mount('/content/drive')

#Path to dataset folder
data_folder = '/content/drive/My Drive/MA/'
# Out:
# Mounted at /content/drive

# %%
#Import required libraries for this notebook
import pandas as pd
from datetime import datetime

# %%
#Read data
signals = 'wind-farm-1-signals-training.csv'
all_data = pd.read_csv(data_folder + signals, delimiter=';')

# %%
#Start EDA

# %%
#Pick a turbine of choice to work with
wtg_data = all_data[all_data.Turbine_ID == 'T09'].reset_index().drop(columns=['index'])
wtg_data['Timestamp'] = pd.to_datetime(wtg_data['Timestamp'])
print(wtg_data.dtypes)
wtg_data.head()
# Out:
# Turbine_ID                            object
# Timestamp                datetime64[ns, UTC]
# Gen_RPM_Max                          float64
# Gen_RPM_Min                          float64
# Gen_RPM_Avg                          float64
#                                 ...
# Grd_Prod_PsbleCap_Max                float64
# Grd_Prod_PsbleCap_Min                float64
# Grd_Prod_PsbleCap_Std                float64
# Gen_Bear2_Temp_Avg                     int64
# Nac_Direction_Avg                    float64
# Length: 83, dtype: object
#   Turbine_ID                 Timestamp  ...  Gen_Bear2_Temp_Avg  Nac_Direction_Avg
# 0        T09 2016-01-01 00:00:00+00:00  ...                  33              214.0
# 1        T09 2016-01-01 00:10:00+00:00  ...                  33              214.0
# 2        T09 2016-01-01 00:20:00+00:00  ...                  33              214.0
# 3        T09 2016-01-01 00:30:00+00:00  ...                  33              214.0
# 4        T09 2016-01-01 00:40:00+00:00  ...                  34              214.0
#
# [5 rows x 83 columns]

# %%
#Checking for gaps
#Dataset starts on 01/01/2016 at 00:00
print('Start: ', wtg_data.iloc[0].Timestamp)

#Dataset ends on 01/09/2017 at 00:00
print('End:', wtg_data.iloc[-1].Timestamp)

#Calculating timedelta and comparing actual with expected number of 10-min intervals
delta = wtg_data.iloc[-1].Timestamp - wtg_data.iloc[0].Timestamp
print('Number of readings in the time period of the dataset..')

#A day has 144 10-minutes
expected = delta.days * 144
print('Expected: ', expected)
actual = wtg_data.shape[0]
print('Actual: ', actual)
if expected > actual:
  print('{} entries (~{} days of data) missing'.format(expected-actual, round((expected-actual)/144)))
# Out:
# Start:  2016-01-01 00:00:00+00:00
# End: 2017-09-01 00:00:00+00:00
# Number of readings in the time period of the dataset..
# Expected:  87696
# Actual:  87156
# 540 entries (~4 days of data) missing

# %%
#T01 has ~4days of gaps
#T06 has ~16days of gaps
#T07 has ~3days of gaps
#T09 has ~4days of gaps
#T11 has ~3days of gaps

# %%
#Locating the gap(s)
wtg_data['Timediff_min'] = wtg_data['Timestamp'].diff().astype('timedelta64[m]')
wtg_data['Gap_Before'] = wtg_data['Timediff_min'] > 10.0
print('Gaps: ')
wtg_data[['Timestamp', 'Timediff_min']][wtg_data['Gap_Before'] | wtg_data.shift(-1)['Gap_Before']]
# Out:
# Gaps:
#                       Timestamp  Timediff_min
# 7570  2016-02-22 13:40:00+00:00          10.0
# 7571  2016-02-22 14:30:00+00:00          50.0
# 12391 2016-03-27 01:50:00+00:00          10.0
# 12392 2016-03-27 03:00:00+00:00          70.0
# 20156 2016-05-20 01:00:00+00:00          10.0
# 20157 2016-05-20 05:20:00+00:00         260.0
# 24300 2016-06-17 23:50:00+00:00          10.0
# 24301 2016-06-18 00:20:00+00:00          30.0
# 28837 2016-07-19 12:20:00+00:00          10.0
# 28838 2016-07-19 12:40:00+00:00          20.0
# 28951 2016-07-20 07:30:00+00:00          10.0
# 28952 2016-07-20 08:10:00+00:00          40.0
# 30967 2016-08-03 08:00:00+00:00          10.0
# 30968 2016-08-03 12:40:00+00:00         280.0
# 34832 2016-08-30 08:40:00+00:00          10.0
# 34833 2016-08-30 20:50:00+00:00         730.0
# 34902 2016-08-31 08:20:00+00:00          10.0
# 34903 2016-08-31 21:20:00+00:00         780.0
# 35702 2016-09-06 10:30:00+00:00          10.0
# 35703 2016-09-06 13:40:00+00:00         190.0
# 37580 2016-09-19 14:30:00+00:00          10.0
# 37581 2016-09-19 14:50:00+00:00          20.0
# 40011 2016-10-06 11:50:00+00:00          10.0
# 40012 2016-10-06 15:40:00+00:00         230.0
# 40684 2016-10-11 07:40:00+00:00          10.0
# 40685 2016-10-11 10:00:00+00:00         140.0
# 64546 2017-03-26 01:50:00+00:00          10.0
# 64547 2017-03-26 03:00:00+00:00          70.0
# 70913 2017-05-09 08:00:00+00:00          10.0
# 70914 2017-05-09 13:00:00+00:00         300.0
# 77227 2017-06-22 09:10:00+00:00          10.0
# 77228 2017-06-22 12:10:00+00:00         180.0
# 79077 2017-07-05 08:20:00+00:00          10.0
# 79078 2017-07-05 20:30:00+00:00         730.0
# 79149 2017-07-06 08:20:00+00:00          10.0
# 79150 2017-07-06 20:40:00+00:00         740.0
# 81164 2017-07-20 20:20:00+00:00          10.0
# 81165 2017-07-21 08:10:00+00:00         710.0
# 82605 2017-07-31 08:10:00+00:00          10.0
# 82606 2017-07-31 08:40:00+00:00          30.0
# 84217 2017-08-11 13:10:00+00:00          10.0
# 84218 2017-08-11 14:40:00+00:00          90.0
# 85045 2017-08-17 08:30:00+00:00          10.0
# 85046 2017-08-17 09:40:00+00:00          70.0
# 85081 2017-08-17 15:30:00+00:00          10.0
# 85082 2017-08-17 16:10:00+00:00          40.0

# %%
wtg_data.set_index('Timestamp')['Timediff_min'].plot()

# %%
wtg_data[wtg_data['Gap_Before']].shape[0]/wtg_data.shape[0]
# Out:
# 0.0002639249076262823

# %%
logs = 'wind-farm-1-logs-training.csv'
logs_data = pd.read_csv(data_folder + logs, delimiter=';')
logs_data = logs_data[logs_data.UnitTitle == 'T01'].reset_index().drop(columns=['index'])
logs_data['TimeDetected'] = pd.to_datetime(logs_data['TimeDetected'])

# %%
logs_data.head()
# Out:
#                TimeDetected  ... UnitTitleDestination
# 0 2016-01-01 00:15:27+00:00  ...                  NaN
# 1 2016-01-01 00:15:44+00:00  ...                  NaN
# 2 2016-01-01 00:45:43+00:00  ...                  NaN
# 3 2016-01-01 01:15:43+00:00  ...                  NaN
# 4 2016-01-01 01:45:43+00:00  ...                  NaN
#
# [5 rows x 5 columns]

# %%
logs_data.set_index('TimeDetected').resample('10T').count().plot()

# %%
merged_df = pd.merge_asof(wtg_data, logs_data, left_on='Timestamp', right_on='TimeDetected')

# %%
merged_df[['Timestamp', 'TimeDetected', 'Remark']].head(10)
# Out:
#                   Timestamp  ...                      Remark
# 0 2016-01-01 00:00:00+00:00  ...                         NaN
# 1 2016-01-01 00:10:00+00:00  ...                         NaN
# 2 2016-01-01 00:20:00+00:00  ...  External power ref.:2000kW
# 3 2016-01-01 00:30:00+00:00  ...  External power ref.:2000kW
# 4 2016-01-01 00:40:00+00:00  ...  External power ref.:2000kW
# 5 2016-01-01 00:50:00+00:00  ...  External power ref.:2000kW
# 6 2016-01-01 01:00:00+00:00  ...  External power ref.:2000kW
# 7 2016-01-01 01:10:00+00:00  ...  External power ref.:2000kW
# 8 2016-01-01 01:20:00+00:00  ...  External power ref.:2000kW
# 9 2016-01-01 01:30:00+00:00  ...  External power ref.:2000kW
#
# [10 rows x 3 columns]
